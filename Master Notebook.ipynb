# %%
# %%bash
# start=$(date +%s.%N)
# #"01" "02" "03"
# months=("all")
# ids=("Junonia_coenia")
# #add glm and rf after cta10 run
# algorithms=("CTA")
# #add 1 and 50 after cta10 run
# predictions=("10")
#
# for id in "${ids[@]}"; do
#     for month in "${months[@]}"; do
#         for algo in "${algorithms[@]}"; do
#             for predic in "${predictions[@]}"; do
#                 Rscript --vanilla scripts/run-sdm-algo.R data/inaturalist/$id/$id-$month.csv $id-$month output/
#             done
#         done
#     done
# done
# end=$(date +%s.%N)
# runtime=$(python -c "print(${end} - ${start})")
#
# echo "Runtime was $runtime"
# Out:
# Data check ...
# No presence column, presence-only data set is supposed.
# Pseudo-absence selection will be computed.
#    done.
#
# Pseudo absence selection...
#    random selection
#    done.
#
# Model evaluation...
#    done.
#
# Model projection...
#    done.
#
# Model axes contribution evaluation...
#    done.
#
# Data check ...
# No presence column, presence-only data set is supposed.
# Pseudo-absence selection will be computed.
#    done.
#
# Pseudo absence selection...
#    random selection
#    done.
#
# Model evaluation...
#    done.
#
# Model projection...
#    done.
#
# Model axes contribution evaluation...
#    done.
#
# Data check ...
# No presence column, presence-only data set is supposed.
# Pseudo-absence selection will be computed.
#    done.
#
# Pseudo absence selection...
#    random selection
#    done.
#
# Model evaluation...
#    done.
#
# Model projection...
#    done.
#
# Model axes contribution evaluation...
#    done.
#
# Data check ...
# ...

# %%
text=input()
# Out:
# yo

# %%
print(text)
# Out:
# yo

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
# %matplotlib inline

species = input("Enter a species here: ")
monthz = ["oct", "nov", "dec"]
algorithmz = ["CTA", "RF"]
predictionz = ["1", "10", "50"]

path = ""
images = []

for month in monthz:
    for algo in algorithmz:
        for prediction in predictionz:
            
            picture = species + "-" + month + "-" + algo + "-" + prediction + "-prediction-" + algo + "-" + prediction + ".png"
            direc = species
            img = Image.open("output/"+picture)
            images.append(img)


'''
plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
'''
# Out:
# Enter a species here: Papilion_glaucus
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-798ab6c027a4> in <module>()
#      19             picture = species + "-" + month + "-" + algo + "-" + prediction + "-prediction-" + algo + "-" + prediction + ".png"
#      20             direc = species
# ---> 21             img = Image.open("output/"+picture)
#      22             images.append(img)
#      23
#
# c:\users\chris\appdata\local\programs\python\python36\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/Papilion_glaucus-oct-CTA-1-prediction-CTA-1.png'
